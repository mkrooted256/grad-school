# %% [markdown]
# # Інтерполяція

# %% [markdown]
# ### Визначник Вандермонда
# Та його значення через добуток
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Поліноми Чебишова
# - https://en.wikipedia.org/wiki/Chebyshev_polynomials
# - Ортогональні між собою
# - For any given n ≥ 1, among the polynomials of degree n with leading coefficient 1 (monic polynomials),
#     $${\displaystyle f(x)={\frac {1}{\,2^{n-1}\,}}\,T_{n}(x)}$$
#     is the one of which the maximal absolute value on the interval [−1, 1] is minimal.
#     $\sup_{x\in[0;1]} f(x) = 2^{-n+1}$
# - **Визначення оптимальних вузлів для поліноміальної інтерполяції**
#
#
# - Інтегрування по методу Чебишова
# - Вузли Чебишова
# - https://en.wikipedia.org/wiki/Chebyshev_nodes

# %% [markdown]
# ### Розділені різниці (для інтерполяції Ньютона)
# - Можна обчислювати динамічним програмуванням
