# %%
import numpy as np
# import sympy as sym
# from sympy import symbols
import matplotlib.pyplot as plt

# %%
def f(t):
    return 6 * t**2 * np.float_power(t**4+t**6, -3/2)

# %%
X = np.linspace(0.1,10,1000)
plt.plot(X, f(X))

# %%
def g(s):
    return (2)*np.float_power(s**4+1,-3/2)

# %%
plt.plot(X, g(X))

# %%
def bump2(x,y):
    return exp
